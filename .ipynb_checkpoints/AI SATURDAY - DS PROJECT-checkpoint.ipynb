# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
Data = pd.read_csv('NIGERIA_DEMOGRAPHICS_DATA.csv')

# %%
Data.head()
# Out:
#              Timestamp Are you a Nigerian?  Gender Age Group Are you married?  \
# 0  10/13/2019 17:45:01                 NaN  Female   18 – 25               No
# 1  10/13/2019 18:13:59                 NaN  Female   18 – 25               No
# 2  10/13/2019 20:11:39                 NaN    Male   36 – 45              Yes
# 3  10/13/2019 20:17:57                 NaN  Female   26 – 35               No
# 4   10/14/2019 6:24:13                 NaN    Male   26 – 35               No
#
#   Do you have kids? Where do you live?  \
# 0                No              Lagos
# 1                No              Lagos
# 2               Yes              Lagos
# 3                No              Lagos
# 4                No              Lagos
#
#   What part of your state do you live in?          Occupation  \
# 0                                   Rural                 NaN
# 1                                   Rural              No Job
# 2                                    City  Financial Services
# 3                                    City            Business
# 4                                   Rural         Engineering
#
#   Are you Happy with your job?  \
# 0                           No
# 1                           No
# 2                          Yes
# 3                          Yes
# 4                          Yes
#
#                                          ...                                          \
# 0                                        ...
# 1                                        ...
# 2                                        ...
# 3                                        ...
# 4                                        ...
#
#   Do you think it is enough for you and your family?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                Yes
#
#   What are your other sources of income?  Do you pay your tax?  \
# 0                                     NaN                   No
# 1                            Free Lancing                   No
# 2                            Free Lancing                  Yes
# 3                      Buying and Selling                  Yes
# 4                              Formal Job                  Yes
#
#   What is your largest form of expense  \
# 0                              Feeding
# 1                       Transportation
# 2                          School Fees
# 3                       Transportation
# 4                       Transportation
#
#   If there was one thing you really wanted to own, what would that be?  \
# 0                                          A Company
# 1                                            A House
# 2                                          A Company
# 3                                              Money
# 4                                          A Company
#
#   How much do you think you earn from all other sources of income in a month  \
# 0                                                NaN
# 1                                            18000.0
# 2                                            40000.0
# 3                                           500000.0
# 4                                                0.0
#
#   On an average, how much do you think you spend in a month?  \
# 0                                              25000
# 1                                              20000
# 2                                             140000
# 3                                             100000
# 4                                              60000
#
#    Do you think Nigeria can get better?  \
# 0                                   Yes
# 1                                   Yes
# 2                                   Yes
# 3                                   Yes
# 4                                   Yes
#
#        In a short sentence, describe your government  \
# 0                                        Frustrating
# 1                     Greedy, self centered and dull
# 2  Our government do not care about what the mass...
# 3  There is discrepancy in Nigeria's governance. ...
# 4  It is a corrupt one lead by inconsiderate fell...
#
#   Please fill your email if you want to be notified once this research is completed.
# 0                              ikeoluwa933@gmail.com
# 1                                                NaN
# 2                      olanrewaju1temitayo@gmail.com
# 3                          adewunmi.fatoki@gmail.com
# 4                              Johnnyark9@gmail.com
#
# [5 rows x 22 columns]

# %%
Data.columns.values
# Out:
# array(['Timestamp', 'Are you a Nigerian?', 'Gender', 'Age Group',
#        'Are you married?', 'Do you have kids?', 'Where do you live?',
#        'What part of your state do you live in?', 'Occupation',
#        'Are you Happy with your job?',
#        'Is this your primary source of income?',
#        'What is your steady/constant income range in a month?',
#        'Do you think it is enough for you and your family?',
#        'What are your other sources of income? ', 'Do you pay your tax?',
#        'What is your largest form of expense',
#        'If there was one thing you really wanted to own, what would that be?',
#        'How much do you think you earn from all other sources of income in a month',
#        'On an average, how much do you think you spend in a month?',
#        'Do you think Nigeria can get better?',
#        'In a short sentence, describe your government',
#        'Please fill your email if you want to be notified once this research is completed.'],
#       dtype=object)

# %% [markdown]
# Since the column headers look very long and clumsy, we would have to rename them into something shorter and understandable.

# %%
Data.rename(columns = {'Are you a Nigerian?': 'Nigerian Citizen',
                       'Age Group': 'Age',
                       'Are you married?': 'Married',
                    'Do you have kids?': 'Parenting' , 
                    'Where do you live?': 'State of Residence', 
                    'What part of your state do you live in?': 'Area of Residence', 
                    'Are you Happy with your job?': 'Job Satisfaction', 
                    'Is this your primary source of income?': 'Primary Income(Job)',
                   'What is your steady/constant income range in a month?': 'Monthly Income(Job)',
                   'Do you think it is enough for you and your family?': 'Income sufficiency',
                   'What are your other sources of income? ': 'Secondary income',
                   'Do you pay your tax?': 'Tax Payment',
                   'What is your largest form of expense': 'Major Monthly Expense',
                   'If there was one thing you really wanted to own, what would that be?': 'Aspiring Possession',
                   'How much do you think you earn from all other sources of income in a month': 'Cumulative Secondary Income',
                   'On an average, how much do you think you spend in a month?': 'Average Monthly Expenditure',
                   'Do you think Nigeria can get better?': 'Is Nigeria Hopeful',
                   'In a short sentence, describe your government': 'Thought about the government',
                   'Please fill your email if you want to be notified once this research is completed.': 'E-mails'
                   }, inplace= True
           )

# %%
Data.head()
# Out:
#              Timestamp Nigerian Citizen  Gender      Age Married Parenting  \
# 0  10/13/2019 17:45:01              NaN  Female  18 – 25      No        No
# 1  10/13/2019 18:13:59              NaN  Female  18 – 25      No        No
# 2  10/13/2019 20:11:39              NaN    Male  36 – 45     Yes       Yes
# 3  10/13/2019 20:17:57              NaN  Female  26 – 35      No        No
# 4   10/14/2019 6:24:13              NaN    Male  26 – 35      No        No
#
#   State of Residence Area of Residence          Occupation Job Satisfaction  \
# 0              Lagos             Rural                 NaN               No
# 1              Lagos             Rural              No Job               No
# 2              Lagos              City  Financial Services              Yes
# 3              Lagos              City            Business              Yes
# 4              Lagos             Rural         Engineering              Yes
#
#                ...               Income sufficiency    Secondary income  \
# 0              ...                               No                 NaN
# 1              ...                               No        Free Lancing
# 2              ...                               No        Free Lancing
# 3              ...                               No  Buying and Selling
# 4              ...                              Yes          Formal Job
#
#   Tax Payment Major Monthly Expense Aspiring Possession  \
# 0          No               Feeding           A Company
# 1          No        Transportation             A House
# 2         Yes           School Fees           A Company
# 3         Yes        Transportation               Money
# 4         Yes        Transportation           A Company
#
#   Cumulative Secondary Income Average Monthly Expenditure  Is Nigeria Hopeful  \
# 0                         NaN                       25000                 Yes
# 1                     18000.0                       20000                 Yes
# 2                     40000.0                      140000                 Yes
# 3                    500000.0                      100000                 Yes
# 4                         0.0                       60000                 Yes
#
#                         Thought about the government  \
# 0                                        Frustrating
# 1                     Greedy, self centered and dull
# 2  Our government do not care about what the mass...
# 3  There is discrepancy in Nigeria's governance. ...
# 4  It is a corrupt one lead by inconsiderate fell...
#
#                          E-mails
# 0          ikeoluwa933@gmail.com
# 1                            NaN
# 2  olanrewaju1temitayo@gmail.com
# 3      adewunmi.fatoki@gmail.com
# 4          Johnnyark9@gmail.com
#
# [5 rows x 22 columns]

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 22 columns):
# Timestamp                       303 non-null object
# Nigerian Citizen                288 non-null object
# Gender                          303 non-null object
# Age                             303 non-null object
# Married                         303 non-null object
# Parenting                       303 non-null object
# State of Residence              303 non-null object
# Area of Residence               303 non-null object
# Occupation                      302 non-null object
# Job Satisfaction                303 non-null object
# Primary Income(Job)             303 non-null object
# Monthly Income(Job)             303 non-null object
# Income sufficiency              303 non-null object
# Secondary income                302 non-null object
# Tax Payment                     303 non-null object
# Major Monthly Expense           303 non-null object
# Aspiring Possession             303 non-null object
# Cumulative Secondary Income     302 non-null float64
# Average Monthly Expenditure     303 non-null int64
# Is Nigeria Hopeful              303 non-null object
# Thought about the government    302 non-null object
# E-mails                         181 non-null object
# dtypes: float64(1), int64(1), object(20)
# memory usage: 28.4+ KB

# %%
Data.shape
# Out:
# (303, 22)

# %% [markdown]
# From the dataset, we desire to drop some columns we might not be working with. These are the 'Timestamp' and 'E-mails' columns. This is because neither of them have little or no impact on our project statement.

# %%
Data.drop(['Timestamp','E-mails'], axis = 1, inplace = True)

# %%
Data.isnull().sum()
# Out:
# Nigerian Citizen                15
# Gender                           0
# Age                              0
# Married                          0
# Parenting                        0
# State of Residence               0
# Area of Residence                0
# Occupation                       1
# Job Satisfaction                 0
# Primary Income(Job)              0
# Monthly Income(Job)              0
# Income sufficiency               0
# Secondary income                 1
# Tax Payment                      0
# Major Monthly Expense            0
# Aspiring Possession              0
# Cumulative Secondary Income      1
# Average Monthly Expenditure      0
# Is Nigeria Hopeful               0
# Thought about the government     1
# dtype: int64

# %% [markdown]
# From the above result, it is discovered that some column values are missing. There are various methods of fixing this. Since we do not have the luxury of datasets, we will be mindful of the method we opt for.
#
# <li>For the 'Nigerian Citizen', we will be replacing the missing values with the most frequent in the column.</li>
# <li>The 'Occupation', 'Secondary income','Cumulative Secondary Income' and 'Thought about the government' columns will be filled with 'No', 'None', 0 and 'No commment' respectively.</li>
# This is because they all have just one missing value and we will choose to almost reflect them with a null input.

# %%
Data.describe(include='all')
# Out:
#        Nigerian Citizen Gender      Age Married Parenting State of Residence  \
# count               288    303      303     303       303                303
# unique                2      3        5       2         2                 20
# top                 Yes   Male  18 – 25      No        No              Lagos
# freq                285    216      181     269       279                229
# mean                NaN    NaN      NaN     NaN       NaN                NaN
# std                 NaN    NaN      NaN     NaN       NaN                NaN
# min                 NaN    NaN      NaN     NaN       NaN                NaN
# 25%                 NaN    NaN      NaN     NaN       NaN                NaN
# 50%                 NaN    NaN      NaN     NaN       NaN                NaN
# 75%                 NaN    NaN      NaN     NaN       NaN                NaN
# max                 NaN    NaN      NaN     NaN       NaN                NaN
#
#        Area of Residence                             Occupation  \
# count                303                                    302
# unique                 4                                     13
# top                Urban  Software Engineering /Computer Design
# freq                 167                                     50
# mean                 NaN                                    NaN
# std                  NaN                                    NaN
# min                  NaN                                    NaN
# 25%                  NaN                                    NaN
# 50%                  NaN                                    NaN
# 75%                  NaN                                    NaN
# max                  NaN                                    NaN
#
#        Job Satisfaction Primary Income(Job) Monthly Income(Job)  \
# count               303                 303                 303
# unique                2                   2                  10
# top                 Yes                 Yes     21,000 – 50,000
# freq                176                 238                  82
# mean                NaN                 NaN                 NaN
# std                 NaN                 NaN                 NaN
# min                 NaN                 NaN                 NaN
# 25%                 NaN                 NaN                 NaN
# 50%                 NaN                 NaN                 NaN
# 75%                 NaN                 NaN                 NaN
# max                 NaN                 NaN                 NaN
#
#        Income sufficiency Secondary income Tax Payment Major Monthly Expense  \
# count                 303              302         303                   303
# unique                  2               17           2                     9
# top                    No             None         Yes               Feeding
# freq                  283              102         176                   102
# mean                  NaN              NaN         NaN                   NaN
# std                   NaN              NaN         NaN                   NaN
# min                   NaN              NaN         NaN                   NaN
# 25%                   NaN              NaN         NaN                   NaN
# 50%                   NaN              NaN         NaN                   NaN
# 75%                   NaN              NaN         NaN                   NaN
# max                   NaN              NaN         NaN                   NaN
#
#        Aspiring Possession  Cumulative Secondary Income  \
# count                  303                 3.020000e+02
# unique                   6                          NaN
# top              A Company                          NaN
# freq                   130                          NaN
# mean                   NaN                 6.627668e+07
# std                    NaN                 8.124313e+08
# min                    NaN                 0.000000e+00
# 25%                    NaN                 5.500000e+01
# 50%                    NaN                 1.500000e+04
# 75%                    NaN                 5.000000e+04
# max                    NaN                 1.000000e+10
#
#         Average Monthly Expenditure Is Nigeria Hopeful  \
# count                  3.030000e+02                303
# unique                          NaN                  2
# top                             NaN                Yes
# freq                            NaN                224
# mean                   1.650782e+08                NaN
# std                    2.872421e+09                NaN
# min                    0.000000e+00                NaN
# 25%                    2.000000e+04                NaN
# 50%                    4.700000e+04                NaN
# 75%                    8.000000e+04                NaN
# max                    5.000000e+10                NaN
#
#        Thought about the government
# count                           302
# unique                          268
# top                         Corrupt
# freq                              7
# mean                            NaN
# std                             NaN
# min                             NaN
# 25%                             NaN
# 50%                             NaN
# 75%                             NaN
# max                             NaN

# %% [markdown]
# ### Fill up all the missing values

# %%
Data.loc[ :,('Nigerian Citizen')] =  Data['Nigerian Citizen'].fillna('Yes')

# %%
Data.loc[:,('Occupation')]=Data['Occupation'].fillna('No')

# %%
Data.loc[:,('Secondary income')] = Data['Secondary income'].fillna('None')

# %%
Data.loc[:,('Cumulative Secondary Income')]= Data['Cumulative Secondary Income'].fillna(0)

# %%
Data.loc[:,('Thought about the government')]= Data['Thought about the government'].fillna(method='pad')

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 20 columns):
# Nigerian Citizen                303 non-null object
# Gender                          303 non-null object
# Age                             303 non-null object
# Married                         303 non-null object
# Parenting                       303 non-null object
# State of Residence              303 non-null object
# Area of Residence               303 non-null object
# Occupation                      303 non-null object
# Job Satisfaction                303 non-null object
# Primary Income(Job)             303 non-null object
# Monthly Income(Job)             303 non-null object
# Income sufficiency              303 non-null object
# Secondary income                303 non-null object
# Tax Payment                     303 non-null object
# Major Monthly Expense           303 non-null object
# Aspiring Possession             303 non-null object
# Cumulative Secondary Income     303 non-null float64
# Average Monthly Expenditure     303 non-null int64
# Is Nigeria Hopeful              303 non-null object
# Thought about the government    303 non-null object
# dtypes: float64(1), int64(1), object(18)
# memory usage: 26.1+ KB

# %% [markdown]
# ## Now we will proceed into enquiring the earnings of most Nigerians in a month.

# %%
data=Data['Monthly Income(Job)'].value_counts()
data
# Out:
# 21,000 – 50,000      82
# 110,000 – 200,000    37
# 81,000 – 100,000     35
# 51,000 – 80,000      33
# 11,000 – 20,000      29
# Below 5000           29
# 201,000 – 300,000    23
# 5000 – 10,000        18
# 301,000 – 500,000     9
# 500,000 – above       8
# Name: Monthly Income(Job), dtype: int64

# %%
Data['Age'].value_counts()
# Out:
# 18 – 25    181
# 26 – 35    104
# 36 – 45     13
# 46 – 55      4
# 56 – 65      1
# Name: Age, dtype: int64

# %%
Data['Occupation'].value_counts()
# Out:
# Software Engineering /Computer Design    50
# Student                                  48
# Engineering                              31
# Entrepreneur                             28
# Financial Services                       27
# No Job                                   25
# Student and Working                      23
# Others                                   18
# Consultant                               16
# Business                                 16
# Health                                   10
# I don’t know                              9
# No                                        1
# Farmer                                    1
# Name: Occupation, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
data.plot(kind='bar',)
plt.title('Monthly Income Rate')
plt.ylabel('Count')
plt.xlabel('Income Range')
plt.xticks(rotation = 90)
plt.show()

# %%
Data.columns
# Out:
# Index(['Nigerian Citizen', 'Gender', 'Age', 'Married', 'Parenting',
#        'State of Residence', 'Area of Residence', 'Occupation',
#        'Job Satisfaction', 'Primary Income(Job)', 'Monthly Income(Job)',
#        'Income sufficiency', 'Secondary income', 'Tax Payment',
#        'Major Monthly Expense', 'Aspiring Possession',
#        'Cumulative Secondary Income', 'Average Monthly Expenditure',
#        'Is Nigeria Hopeful', 'Thought about the government'],
#       dtype='object')

# %% [markdown]
# ## Replacing the values with the mean of each range for Monthly Income

# %%
Data['Monthly Income(Job)'] = Data['Monthly Income(Job)'].replace('Below 5000',2500)
Data['Monthly Income(Job)'] = Data['Monthly Income(Job)'].replace('5000 – 10,000',7500)
Data['Monthly Income(Job)'] = Data['Monthly Income(Job)'].replace('11,000 – 20,000',15500)
Data['Monthly Income(Job)'] = Data['Monthly Income(Job)'].replace('21,000 – 50,000',35500)
Data['Monthly Income(Job)'] = Data['Monthly Income(Job)'].replace('51,000 – 80,000',65500)
Data['Monthly Income(Job)'] = Data['Monthly Income(Job)'].replace('81,000 – 100,000',90500)
Data['Monthly Income(Job)'] = Data['Monthly Income(Job)'].replace('110,000 – 200,000',15500)
Data['Monthly Income(Job)'] = Data['Monthly Income(Job)'].replace('201,000 – 300,000',250500)
Data['Monthly Income(Job)'] = Data['Monthly Income(Job)'].replace('301,000 – 500,000',400500)
Data['Monthly Income(Job)'] = Data['Monthly Income(Job)'].replace('500,000 – above',600000)

# %%
Data['Monthly Income(Job)'].head(5)
# Out:
# 0      2500
# 1     15500
# 2     15500
# 3    250500
# 4     15500
# Name: Monthly Income(Job), dtype: int64

# %%
Data.head()
# Out:
#   Nigerian Citizen  Gender      Age Married Parenting State of Residence  \
# 0              Yes  Female  18 – 25      No        No              Lagos
# 1              Yes  Female  18 – 25      No        No              Lagos
# 2              Yes    Male  36 – 45     Yes       Yes              Lagos
# 3              Yes  Female  26 – 35      No        No              Lagos
# 4              Yes    Male  26 – 35      No        No              Lagos
#
#   Area of Residence          Occupation Job Satisfaction Primary Income(Job)  \
# 0             Rural                  No               No                  No
# 1             Rural              No Job               No                  No
# 2              City  Financial Services              Yes                 Yes
# 3              City            Business              Yes                 Yes
# 4             Rural         Engineering              Yes                 Yes
#
#    Monthly Income(Job) Income sufficiency    Secondary income Tax Payment  \
# 0                 2500                 No                None          No
# 1                15500                 No        Free Lancing          No
# 2                15500                 No        Free Lancing         Yes
# 3               250500                 No  Buying and Selling         Yes
# 4                15500                Yes          Formal Job         Yes
#
#   Major Monthly Expense Aspiring Possession  Cumulative Secondary Income  \
# 0               Feeding           A Company                          0.0
# 1        Transportation             A House                      18000.0
# 2           School Fees           A Company                      40000.0
# 3        Transportation               Money                     500000.0
# 4        Transportation           A Company                          0.0
#
#    Average Monthly Expenditure Is Nigeria Hopeful  \
# 0                        25000                Yes
# 1                        20000                Yes
# 2                       140000                Yes
# 3                       100000                Yes
# 4                        60000                Yes
#
#                         Thought about the government
# 0                                        Frustrating
# 1                     Greedy, self centered and dull
# 2  Our government do not care about what the mass...
# 3  There is discrepancy in Nigeria's governance. ...
# 4  It is a corrupt one lead by inconsiderate fell...

# %% [markdown]
# ## Replacing the values with the mean of each range for Age

# %%
Data['Age'] = Data['Age'].replace('18 – 25',22)
Data['Age'] = Data['Age'].replace('26 – 35',31)
Data['Age'] = Data['Age'].replace('36 – 45',41)
Data['Age'] = Data['Age'].replace('46 – 55',51)
Data['Age'] = Data['Age'].replace('56 – 65',61)

# %%
Data['Age'].head(5)
# Out:
# 0    22
# 1    22
# 2    41
# 3    31
# 4    31
# Name: Age, dtype: int64

# %% [markdown]
# ### Let's create a column for Over all monthly income and how much is left after all expenses have been removed

# %%
Data['Grand Monthly Income'] = Data['Monthly Income(Job)'] + Data['Cumulative Secondary Income']

# %%
Data['Balance(Monthly)'] = Data['Grand Monthly Income'] - Data['Average Monthly Expenditure']

# %%
Data.head()
# Out:
#   Nigerian Citizen  Gender  Age Married Parenting State of Residence  \
# 0              Yes  Female   22      No        No              Lagos
# 1              Yes  Female   22      No        No              Lagos
# 2              Yes    Male   41     Yes       Yes              Lagos
# 3              Yes  Female   31      No        No              Lagos
# 4              Yes    Male   31      No        No              Lagos
#
#   Area of Residence          Occupation Job Satisfaction Primary Income(Job)  \
# 0             Rural                  No               No                  No
# 1             Rural              No Job               No                  No
# 2              City  Financial Services              Yes                 Yes
# 3              City            Business              Yes                 Yes
# 4             Rural         Engineering              Yes                 Yes
#
#         ...           Secondary income Tax Payment Major Monthly Expense  \
# 0       ...                       None          No               Feeding
# 1       ...               Free Lancing          No        Transportation
# 2       ...               Free Lancing         Yes           School Fees
# 3       ...         Buying and Selling         Yes        Transportation
# 4       ...                 Formal Job         Yes        Transportation
#
#   Aspiring Possession Cumulative Secondary Income Average Monthly Expenditure  \
# 0           A Company                         0.0                       25000
# 1             A House                     18000.0                       20000
# 2           A Company                     40000.0                      140000
# 3               Money                    500000.0                      100000
# 4           A Company                         0.0                       60000
#
#    Is Nigeria Hopeful                       Thought about the government  \
# 0                 Yes                                        Frustrating
# 1                 Yes                     Greedy, self centered and dull
# 2                 Yes  Our government do not care about what the mass...
# 3                 Yes  There is discrepancy in Nigeria's governance. ...
# 4                 Yes  It is a corrupt one lead by inconsiderate fell...
#
#   Grand Monthly Income Balance(Monthly)
# 0               2500.0         -22500.0
# 1              33500.0          13500.0
# 2              55500.0         -84500.0
# 3             750500.0         650500.0
# 4              15500.0         -44500.0
#
# [5 rows x 22 columns]

# %%
Data['Balance(Monthly)'].value_counts()
# Out:
#  15500.0     20
#  25500.0     15
#  40500.0     12
#  5500.0      12
# -4500.0      12
#  500.0        9
# -34500.0      8
#  35500.0      7
#  10500.0      7
#  20500.0      7
# -2500.0       6
#  30500.0      6
#  45500.0      5
#  7500.0       5
# -12500.0      5
#  400500.0     5
#  2500.0       4
# -44500.0      4
# -17500.0      4
#  115500.0     4
#  50500.0      4
# -7500.0       3
# -27500.0      3
#  90500.0      3
# -84500.0      3
# -9500.0       3
#  65500.0      3
#  85500.0      3
#  100500.0     3
#  105500.0     3
#              ..
#  53500.0      1
#  700350.0     1
#  22498.0      1
#  28500.0      1
#  60500.0      1
#  165500.0     1
# -124500.0     1
# -21500.0      1
#  120500.0     1
#  300000.0     1
#  650500.0     1
#  105450.0     1
# -97500.0      1
#  35470.0      1
#  400000.0     1
#  173500.0     1
#  800500.0     1
#  15495.0      1
# -1500.0       1
#  35505.0      1
#  220500.0     1
#  80500.0      1
#  102500.0     1
#  135500.0     1
#  220000.0     1
#  450500.0     1
#  18000.0      1
#  75500.0      1
#  85470.0      1
# -3500.0       1
# Name: Balance(Monthly), Length: 123, dtype: int64

# %%
Data['Balance(Monthly)'].max()
# Out:
# 9999995500.0

# %%
outlier = Data['Balance(Monthly)'] == 9999995500.0

# %%
Data[outlier]
# Out:
#     Nigerian Citizen  Gender  Age Married Parenting State of Residence  \
# 256              Yes  Female   31      No        No               Ogun
#
#     Area of Residence Occupation Job Satisfaction Primary Income(Job)  \
# 256             Urban     Others              Yes                 Yes
#
#           ...         Secondary income Tax Payment Major Monthly Expense  \
# 256       ...             Free Lancing         Yes               Feeding
#
#     Aspiring Possession Cumulative Secondary Income  \
# 256              Others                1.000000e+10
#
#     Average Monthly Expenditure  Is Nigeria Hopeful  \
# 256                       40000                 Yes
#
#      Thought about the government Grand Monthly Income Balance(Monthly)
# 256                      Well...          1.000004e+10     9.999996e+09
#
# [1 rows x 22 columns]

# %%
Data['Balance(Monthly)'].min()
# Out:
# -39999400000.0

# %%
underlier = Data['Balance(Monthly)'] == -39999400000.0

# %%
Data[underlier]
# Out:
#     Nigerian Citizen  Gender  Age Married Parenting State of Residence  \
# 225               No  Female   61      No        No            Plateau
#
#     Area of Residence Occupation Job Satisfaction Primary Income(Job)  \
# 225             Rural     Others               No                  No
#
#           ...            Secondary income Tax Payment Major Monthly Expense  \
# 225       ...         Betting (Bet Naija)          No  Clothing and Jewelry
#
#     Aspiring Possession Cumulative Secondary Income  \
# 225              A Boat                1.000000e+10
#
#     Average Monthly Expenditure  Is Nigeria Hopeful  \
# 225                 50000000000                  No
#
#      Thought about the government Grand Monthly Income Balance(Monthly)
# 225                     Not good          1.000060e+10    -3.999940e+10
#
# [1 rows x 22 columns]

# %% [markdown]
# # Data Visualization

# %%
plt.rcParams['figure.figsize'] = (10, 5)
sns.countplot(Data['Job Satisfaction'], palette = 'pink')
plt.title('People Opinions about Job Satisfaction', fontsize = 20)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (10, 5)
sns.countplot(Data['Area of Residence'], palette = 'pink')
plt.title('Area of Residence', fontsize = 20)
plt.show()

# %%
Data.columns
# Out:
# Index(['Nigerian Citizen', 'Gender', 'Age', 'Married', 'Parenting',
#        'State of Residence', 'Area of Residence', 'Occupation',
#        'Job Satisfaction', 'Primary Income(Job)', 'Monthly Income(Job)',
#        'Income sufficiency', 'Secondary income', 'Tax Payment',
#        'Major Monthly Expense', 'Aspiring Possession',
#        'Cumulative Secondary Income', 'Average Monthly Expenditure',
#        'Is Nigeria Hopeful', 'Thought about the government',
#        'Grand Monthly Income', 'Balance(Monthly)'],
#       dtype='object')

# %%
plt.rcParams['figure.figsize'] = (10, 5)
sns.countplot(Data['Age'], palette = 'pink')
plt.title('Age', fontsize = 20)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (10, 5)
sns.countplot(Data['Tax Payment'], palette = 'pink')
plt.title('Tax Payment', fontsize = 20)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (10, 5)
sns.countplot(Data['Is Nigeria Hopeful'], palette = 'pink')
plt.title('Is Nigeria Hopeful', fontsize = 20)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (30, 10)
Data['State of Residence'].value_counts().plot(kind = 'bar')
plt.title('State of Residence', fontsize = 20)
plt.show()
